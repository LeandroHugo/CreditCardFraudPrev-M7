# %% [markdown]
# # Challenge
#
# Another approach to identifying fraudulent transactions is to look for outliers in the data. Standard deviation or quartiles are often used to detect outliers. Using this starter notebook, code two Python functions:
#
# * One that uses standard deviation to identify anomalies for any cardholder.
#
# * Another that uses interquartile range to identify anomalies for any cardholder.
#
# ## Identifying Outliers using Standard Deviation

# %%
# Initial imports
import pandas as pd
import numpy as np
import random
from sqlalchemy import create_engine

# %%
# Create a connection to the database
engine = create_engine("postgresql://postgres:postgres@localhost:5432/fraud_detection")

# %%
# Write function that locates outliers using standard deviation
def outliers(data):
    mean = np.mean(data)
    std = np.std(data)
    outliers = []
    for x in data:
        z_score = (x - mean) / std
        if np.abs(z_score) > 3:
            outliers.append(x)
    return outliers

# %%
# Find anomalous transactions for 3 random card holders
card_holder_1 = pd.read_sql("SELECT * FROM card_holder WHERE id = 2", engine)
card_holder_2 = pd.read_sql("SELECT * FROM card_holder WHERE id = 18", engine)
card_holder_3 = pd.read_sql("SELECT * FROM card_holder WHERE id = 25", engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/alpacaenv/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/envs/alpacaenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~/opt/anaconda3/envs/alpacaenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~/opt/anaconda3/envs/alpacaenv/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# ...

# %% [markdown]
# ## Identifying Outliers Using Interquartile Range

# %%
# Write a function that locates outliers using interquartile range

# %%
# Find anomalous transactions for 3 random card holders
